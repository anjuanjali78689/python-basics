# %% [markdown]
# <a href="https://colab.research.google.com/github/anjuanjali78689/python-basics/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("enter the number"))
num2 = int (input("enter the number"))
print(num1+ num2)
# Out:
# enter the number10
# enter the number20
# 30

# %%
print("hello world")
# Out:
# hello world

# %%
name = 'Anjali'
print(name)
# Out:
# Anjali

# %%
a = int(input("enter a value : "))
b = int(input("enter b value : "))
a = a+b
b = a-b
a=a-b
print("a :",a)
print("b :",b)
# Out:
# enter a value : 10
# enter b value : 4
# a : 4
# b : 10

# %%
num1=10
num2=3.14
name="Python"
val=False
print( num1,num2,name,val,sep ="\n")
# Out:
# 10
# 3.14
# Python
# False

# %%
a,b,c = input("enter the name : "),input("enter the age : "),input("enter the year : ")
print(a,b,c)
# Out:
# enter the name : anjali
# enter the age : 24
# enter the year : 2002
# anjali 24 2002

# %%
num1 =25
name = "Hello"
num2 = 3.14
val = True
print(type(num1),"\n",type(name),"\n",type(num2),"\n",type(val))
# Out:
# <class 'int'>
#  <class 'str'>
#  <class 'float'>
#  <class 'bool'>

# %%
a,b,c =input("enter the name : "),input("enter the age : "),input("enter the city : ")
print("My name is",a,"age is",b,"and live in",c)
# Out:
# enter the name : anju
# enter the age : 25
# enter the city : dvg
# My name is anju age is 25 and live in dvg

# %%
a = input("enter the integer value")
print(float(a))
# Out:
# enter the integer value10
# 10.0
# enter the integer value10
# 10.0

# %%
a ="100"
b=int(a)
print(type(a),b,type(b),sep="\n")
# Out:
# <class 'str'>
# 100
# <class 'int'>

# %%
a=int(input("enter a value"))
b=int(input("enter b value"))
c=int(a%b)
print(c)
# Out:
# enter a value10
# enter b value6
# 4

# %%
n = int(input("enter n vlaue : "))
c=n*n
print(c)
# Out:
# enter n vlaue : 6
# 36

# %%
num1 = int(input("enter a number : "))
num2 = int(input("enter a number : "))
print(f"sum is",num1+num2)
# Out:
# enetr a number : 10
# enter a number : 13
# sum is 23

# %%
num1=int(input("enter a value : "))
num2=int(input("enter a value : "))
print(f"substarcted value is ",num2-num1)
# Out:
# enter a value : 12
# enter a value : 22
# substarcted value is  10

# %%
num1=int(input("enter the vlaue : "))
num2 = int(input("enter the value : "))
print(f"multiplied vaue ",num1*num2)
# Out:
# enter the vlaue : 29
# enter the value : 45
# multiplied vaue  1305

# %%
num1=int(input("enter a value : "))
num2=int(input("enter a value : "))
print(f"divided value is : ",num1/num2)
# Out:
# enter a value : 23
# enter a value : 35
# divided value is :  0.6571428571428571

# %%
num1=int(input("enter the 1st value : "))
num2=int(input("enter the 2nd value : "))
num3=int(input("enter the 3rd value : "))
print(f"sum value is :",num1+num2+num3)
# Out:
# enter the 1st value : 12
# enter the 2nd value : 34
# enter the 3rd value : 56
# sum value is : 102

# %%
num1=int(input("enter a value"))
print(f"the value which is multiplied by 10 is :{num1*10}")
# Out:
# enter a value13
# the value which is multiplied by 10 is :130

# %%
A=float(input("enter a A value : "))
B=float(input("enter a B value : "))
C=float(input("enter a C value : "))
D= A-B-C
print(f"The Value of D: {D}")
# Out:
# enter a A value : 3.5
# enter a B value : 4.3
# enter a C value : 4.5
# The Value of D: -5.3

# %%
A=int(input("enter a 1st value : "))
B=int(input("enter a 2nd value : "))
C=int(input("enter a 3rd value : "))
print(f"Multified value is :{A*B*C} ")
# Out:
# enter a 1st value : 12
# enter a 2nd value : 12
# enter a 3rd value : 23
# Multified value is :3312
